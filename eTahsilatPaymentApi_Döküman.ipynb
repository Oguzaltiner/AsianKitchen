# %% [markdown]
# <a href="https://colab.research.google.com/github/Oguzaltiner/AsianKitchen/blob/master/eTahsilatPaymentApi_D%C3%B6k%C3%BCman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ENDPOİNTLER

# %% [markdown]
# ##BANK
#
# **METOD TYPE :** GET
#
# **METOD İŞLEVİ:**  TÜM BANKALARI LİSTELER _
#
# **METOD CURL:**
# curl -X 'GET' \
#   'https://tahsilat.elogo.com.tr/etahsilatpaymentapitest/bank' \
#   -H 'accept: */*'
#
#
# **RESULT PARAMETERS:**  {
#
#
# *   bankId :
# *   bankName
# *   isPf
# *   apiBankParametersMatch:
#
# [
#   * apiParameter:
#   * bankParameter:
#
# ]
#
#
# }

# %% [markdown]
# ##BİNQUERY
#
# **METOD TYPE :** GET
#
# **METOD İŞLEVİ:**  KART NUMARASINA GÖRE BİN SORGULAMASI YAPAR
#
# **METOD CURL:**
# curl -X 'GET' \
#   'https://tahsilat.elogo.com.tr/etahsilatpaymentapitest/binquery'
#
# **REQUEST PARAMETERS:**
#
#  {
#
#
# *   cardNumber  **(Required)**
# *   apiFirmHash
#
#
#
# }
#
# **RESULT PARAMETERS:**
#
#   {
#
#
# *   bankId :
# *   bankName
# *   isPf
# *   apiBankParametersMatch:
#
# [
#   * apiParameter:
#   * bankParameter:
#
# ]
#
#
# }

# %% [markdown]
# ##CARDBRAND-ALL
#
# **METOD TYPE :** GET
#
# **METOD İŞLEVİ:** Tüm Kart Brandlerini listeler.
#
# **METOD CURL:**
# curl -X 'GET' \
#   'https://tahsilat.elogo.com.tr/etahsilatpaymentapitest/CardBrand/all' \
#   -H 'accept: */*'
#
#
#
# **RESULT PARAMETERS:**
#
# {
#
#
# *   id:
# *   type:
# *   name:
# *   image:
#
#
#
# }

# %% [markdown]
# ##CARDBRAND-GET-BRAND-FROM-CARD
#
# **METOD TYPE :** GET
#
# **METOD İŞLEVİ:** Gönderilen Kart Numarasına göre Brand Sorgular.
#
# **METOD CURL:**
# curl -X 'GET' \
#   'https://tahsilat.elogo.com.tr/etahsilatpaymentapitest/CardBrand/all' \
#   -H 'accept: */*'
#
#
#
# **RESULT PARAMETERS:**
#
# {
#
#
# <!-- *   id:
# *   type:
# *   name:
# *   image: -->
#
#
#
# }

# %% [markdown]
# ##CARDBRAND
# **METOD TYPE :** GET
#
# **METOD İŞLEVİ:** Gönderilen Kart Numarasına göre Brand Sorgular.
#
# **METOD CURL:**
# curl https://tahsilat.elogo.com.tr/etahsilatpaymentapitest/CardBrand
#
#
#
# **RESULT PARAMETERS:**
#
# {
#
#
# *   type:
# *   id:
# *   name:
# *   image:
# *   visa_MC_AmEx:
#
#
#
# }

# %% [markdown]
# ##CUSTOMERS
# **METOD TYPE :** GET
#
# **METOD İŞLEVİ:** İlgili APİKey'in müşterilerini listeler.
#
# **METOD CURL:**
# curl -X 'GET' \
#   'https://tahsilat.elogo.com.tr/etahsilatpaymentapitest/customers' \
#   -H 'accept: text/plain'
#
#
#
# **RESULT PARAMETERS:**
#
# {
#
#
# *   customerid:
# *   firmid:
# *   customercode:
# *   customername:
# *   taxcode:
# *   tccode:
# *   taxoffice:
# *   countryid:
# *   cityid:
# *   districtid:
# *   postalcode:
# *   address:
# *   phone:
# *   mobile:
# *   email:
# *   status:
#
#
#
# }

# %% [markdown]
# ##Firm
# **METOD TYPE :** POST
#
# **METOD İŞLEVİ:** Firma oluşturur.
#
# **METOD CURL:**
# curl  https://tahsilat.elogo.com.tr/etahsilatpaymentapitest/firm
#
# **REQUEST PARAMETERS:**
#
# {
#
#
# *  "firmName": "string",
# *  "licenseKey": "string",
# *  "taxCode": "string",
# *  "email": "string",
# *  "phone": "string",
# *  "firmShortName": "string",
# *  "address": "string",
# *  "taxOffice": "string",
# *  "webAddress": "string",
# *  "fax": "string",
# *  "cityId": 0,
# *  "district": "string"
#
# }
#
# **RESULT PARAMETERS:**
#
# {
#
#
#
#
# }

# %% [markdown]
# ##Firm/Create-from-partner
# **METOD TYPE :** POST
#
# **METOD İŞLEVİ:** Firma ile birlikte Sanal Pos oluşturur.
#
# **METOD CURL:**
# curl https://tahsilat.elogo.com.tr/etahsilatpaymentapitest/firm/create-from-partner
#
# **REQUEST PARAMETERS:**
#
# {
#
#  {
#    * "firmInformation": {
#    * "firmName": "string",
#    * "licenseKey": "string",
#    * "taxCode": "string",
#    * "email": "string",
#    * "phone": "string",
#    * "firmShortName": "string",
#    * "address": "string",
#    * "taxOffice": "string",
#    * "webAddress": "string",
#    * "fax": "string",
#    * "cityId": 0,
#    * "district": "string"
#   },
#   "posInformation": {
#    * "bankId": 0,
#    * "posDisplayName": "string",
#    * "istest": true,
#    * "isDefaultPos": true,
#    * "isManufacturer": true,
#    * "merchantId": "string",
#    * "terminalId": "string",
#    * "username": "string",
#    * "password": "string",
#    * "storeKey": "string",
#    * "installmentList": [
#       {
#       *  "installment": 0,
#       *  "termDays": 0,
#       *  "commissionRate": "string",
#       *  "serviceCommissionRate": "string",
#       *  "extraInstallmentCount": 0,
#       *  "extraInstallmentLowLimit": "string",
#       *  "extraInstallmentUpLimit": "string",
#       *  "deferralCount": 0,
#       *  "deferralLowLimit": "string",
#       *  "deferralUpLimit": "string",
#       *  "amountLowerLimit": "string",
#       *  "amountUpperLimit": "string",
#       *  "termUpLimit": "string"
#       }
#     ]
#   }
# }
#
# }
#
# **RESULT PARAMETERS:**
#
# {
#
#
#
# }

# %% [markdown]
# ##FirmContracts
# **METOD TYPE :** GET
#
# **METOD İŞLEVİ:** Firma sözleşmelerini getirir.
#
# **METOD CURL:**
# curl  curl -X 'GET' \
#   'https://tahsilat.elogo.com.tr/etahsilatpaymentapitest/firmcontracts' \
#   -H 'accept: text/plain'
#
#
# **RESULT PARAMETERS:**
#
# {
#
#
# *   firmcontractid   -int
# *   firmid              -int
# *   contract         -(string(html))
# *   contracttype      -int
#
#
#
#
#
# }

# %% [markdown]
# ##Installments
# **METOD TYPE :** GET
#
# **METOD İŞLEVİ:** Taksitleri  listeler.
#
# **METOD CURL:**
# https://tahsilat.elogo.com.tr/etahsilatpaymentapitest/installments
#
# **REQUEST PARAMETERS:**
#
#
#
# *   CardNumber  **Required**
# *   VpId
# *   Amount       **Required**
#
#
#
# **RESULT PARAMETERS:**
#
# {
#
#
# * "installmentList":
#
#  [ {
# *         *   "bankName": null,
# *         *   "bankImage": null,
# *         *   "month": 1,
# *         *   "monthlyComission": 0,
# *         *   "monthlyAmount": 0.01,
# *         *   "totalAmount": 0.01,
# *         *   "extraInstallmentCount": 0,
# *         *   "deferralCount": 0
#
#  }  ],
#
# *    "vpId": 195,
# *    "selectedBank": "PARATİKA",
# *    "selectedBankId": 22,
# *    "selectedModalId": 1,
# *    "cardType": "MasterCard",
# *    "cardBrand": "0",
# *    "cardOwner": "AKBANK T.A.Ş.",
# *    "image": null,
# *    "amount": "0,01",
# *    "manufacturerCard": "False",
# *    "minAmountAlert": null,
# *    "maxAmountAlert": null,
# *    "errorMessage": null
# }

# %% [markdown]
# ##Installments/html-table
# **METOD TYPE :** GET
#
# **METOD İŞLEVİ:** Taksitleri  Html olarak listeler.
#
# **METOD CURL:**
# 'https://tahsilat.elogo.com.tr/etahsilatpaymentapitest/installments/html-table
#
# **REQUEST PARAMETERS:**
#
#
#
# *   Amount
#
#
#
# **RESULT PARAMETERS:**
#
# {
#
#
# ```
# <html>
#
# </html>
# ```
#
#
# }

# %% [markdown]
# ##Installments/html-table
# **METOD TYPE :** GET
#
# **METOD İŞLEVİ:** Taksitleri  FirmToken'a göre listeler
#
# **METOD CURL:**
# 'https://tahsilat.elogo.com.tr/etahsilatpaymentapitest/installments/get-by-firmtoken
#
# **REQUEST PARAMETERS:**
#
#
#
# *   CardNumber
# *   apiFirmHash
# *   VpId
# *   Amount
#
#
#
# **RESULT PARAMETERS:**
#
# {
#
#
#
# }

# %% [markdown]
# ##Installments/html-table-by-hash
# **METOD TYPE :** GET
#
# **METOD İŞLEVİ:** Taksitleri  FirmToken'a göre html-table olarak getirir.
#
# **METOD CURL:**
# 'https://tahsilat.elogo.com.tr/etahsilatpaymentapitest/installments/html-table-by-hash
#
# **REQUEST PARAMETERS:**
#
#
#
# *   apiFirmHash
# *   Amount
#
#
#
# **RESULT PARAMETERS:**
#
# {
#
#
#
# }
